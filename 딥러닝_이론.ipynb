# %% [markdown]
# <a href="https://colab.research.google.com/github/ghsahsh9379/AI-study/blob/main/%EB%94%A5%EB%9F%AC%EB%8B%9D_%EC%9D%B4%EB%A1%A0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# %%
키 = 170
신발 = 260


# 신발 = 키 * a + b
a = tf.Variable(0.1)
b = tf.Variable(0.2)

print(a, b)
def 손실함수():
    예측값 = (키*a+b)
    return tf.square(260 - 예측값)


opt = tf.keras.optimizers.Adam(learning_rate=0.1)

for i in range(300):
    opt.minimize(손실함수, var_list=[a, b])
    print(a, b)
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.1> <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.2>
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.20000231> <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.30000234>
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.2997461> <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.3997461>
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.399031> <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.499031>
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.4976313> <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.59763134>
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.5952929> <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.69529295>
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.69173265> <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.79173267>
# ...

# %%
train_x = [1,2,3,4,5,6,7]
train_y = [3,5,7,9,11,13,15]

a=tf.Variable(0.1)
b=tf.Variable(0.1)

# %%
opt = tf.keras.optimizers.Adam(learning_rate=0.01)

def 손실함수(a,b):
  예측_y = train_x * a+b
  return tf.keras.losses.mse(train_y,예측_y)

for i in range(3000):
  opt.minimize(lambda:손실함수(a,b),var_list=[a,b])
  print(a.numpy(),b.numpy())
# Out:
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# 2.0 0.99999994
# ...

# %%
print(a,b)
# Out:
# <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.1> <tf.Variable 'Variable:0' shape=() dtype=float32, numpy=0.1>
